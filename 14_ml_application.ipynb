# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewwells991/mds_thesis/blob/main/14_ml_application.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Loading packages
import pandas as pd
import pickle
import matplotlib.pyplot as plt

# %%
#Loading models
#rf_std = pickle.load(open('/content/gdrive/MyDrive/mds_thesis/8_saved_models/rf_std', 'rb'))
#rf_wgt = pickle.load(open('/content/gdrive/MyDrive/mds_thesis/8_saved_models/rf_wgt', 'rb'))
#xgb_std = pickle.load(open('/content/gdrive/MyDrive/mds_thesis/8_saved_models/xgb_std', 'rb'))
#knn_std = pickle.load(open('/content/gdrive/MyDrive/mds_thesis/8_saved_models/knn_std', 'rb'))
rf_over = pickle.load(open('/content/gdrive/MyDrive/mds_thesis/8_saved_models/rf_over', 'rb'))
#xgb_over = pickle.load(open('/content/gdrive/MyDrive/mds_thesis/8_saved_models/xgb_over', 'rb'))

#rf_urban_over = pickle.load(open('/content/gdrive/MyDrive/mds_thesis/8_saved_models/rf_urban_over', 'rb'))
#rf_semi_urban_over = pickle.load(open('/content/gdrive/MyDrive/mds_thesis/8_saved_models/rf_semi_urban_over', 'rb'))
#rf_rural_over = pickle.load(open('/content/gdrive/MyDrive/mds_thesis/8_saved_models/rf_rural_over', 'rb'))

# %% [markdown]
# ###Urban sites: 2_5, 2_10, 2_12, 2_13, 2_18, 2_19, 2_20, 2_21, 2_22, 2_24, 2_27, 7_1, 7_2, 7_3, 7_4, 7_9, 7_12, 7_13, 7_14
#
# ###Semi-Urban sites: 2_8, 2_11, 2_14, 2_23, 2_25, 2_26, 4_1, 4_5, 4_8, 4_9, 7_6, 7_10, 7_15, 10_1, 10_2, 13_2, 16_1, 16_4
#
# ###Rural sites: 2_6, 2_9, 2_15, 2_16, 2_28, 4_2, 4_13, 4_17, 4_19, 4_22, 7_7, 10_3, 13_4, 13_5, 13_6, 13_7, 13_10, 16_2, 16_3

# %% [markdown]
# ##Project 2_5

# %%
# %%capture
proj_2_5_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_5_yr_21_combined_pixel_ob.csv')
proj_2_5_21 = proj_2_5_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_5_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_5_yr_20_pixel.csv')
proj_2_5_20 = proj_2_5_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_5_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_5_yr_19_pixel.csv')
proj_2_5_19 = proj_2_5_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_5_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_5_yr_18_pixel.csv')
proj_2_5_18 = proj_2_5_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_5_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_5_yr_17_pixel.csv')
proj_2_5_17 = proj_2_5_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_5_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_5_yr_16_pixel.csv')
proj_2_5_16 = proj_2_5_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_5_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_5_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_5_predictions = proj_2_5_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_5_predictions)

# %% [markdown]
# ## Project 2_6

# %%
# %%capture
proj_2_6_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_6_yr_21_combined_pixel_ob.csv')
proj_2_6_21 = proj_2_6_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_6_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_6_yr_20_pixel.csv')
proj_2_6_20 = proj_2_6_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_6_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_6_yr_19_pixel.csv')
proj_2_6_19 = proj_2_6_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_6_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_6_yr_18_pixel.csv')
proj_2_6_18 = proj_2_6_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_6_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_6_yr_17_pixel.csv')
proj_2_6_17 = proj_2_6_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_6_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_6_yr_16_pixel.csv')
proj_2_6_16 = proj_2_6_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_6_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_6_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_6_predictions = proj_2_6_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_6_predictions)

# %% [markdown]
# ## Project 2_8

# %%
# %%capture
proj_2_8_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_8_yr_21_combined_pixel_ob.csv')
proj_2_8_21 = proj_2_8_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_8_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_8_yr_20_pixel.csv')
proj_2_8_20 = proj_2_8_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_8_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_8_yr_19_pixel.csv')
proj_2_8_19 = proj_2_8_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_8_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_8_yr_18_pixel.csv')
proj_2_8_18 = proj_2_8_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_8_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_8_yr_17_pixel.csv')
proj_2_8_17 = proj_2_8_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_8_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_8_yr_16_pixel.csv')
proj_2_8_16 = proj_2_8_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_8_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_8_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_8_predictions = proj_2_8_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_8_predictions)

# %% [markdown]
# ## Project 2_9

# %%
# %%capture
proj_2_9_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_9_yr_21_combined_pixel_ob.csv')
proj_2_9_21 = proj_2_9_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_9_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_9_yr_20_pixel.csv')
proj_2_9_20 = proj_2_9_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_9_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_9_yr_19_pixel.csv')
proj_2_9_19 = proj_2_9_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_9_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_9_yr_18_pixel.csv')
proj_2_9_18 = proj_2_9_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_9_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_9_yr_17_pixel.csv')
proj_2_9_17 = proj_2_9_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#proj_2_9_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_9_yr_16_pixel.csv')
#proj_2_9_16 = proj_2_9_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_9_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_9_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_9_predictions = proj_2_9_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_9_predictions)

# %% [markdown]
# ## Project 2_10

# %%
# %%capture
proj_2_10_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_10_yr_21_combined_pixel_ob.csv')
proj_2_10_21 = proj_2_10_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_10_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_10_yr_20_pixel.csv')
proj_2_10_20 = proj_2_10_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_10_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_10_yr_19_pixel.csv')
proj_2_10_19 = proj_2_10_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_10_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_10_yr_18_pixel.csv')
proj_2_10_18 = proj_2_10_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_10_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_10_yr_17_pixel.csv')
proj_2_10_17 = proj_2_10_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_10_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_10_yr_16_pixel.csv')
proj_2_10_16 = proj_2_10_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_10_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_10_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_10_predictions = proj_2_10_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_10_predictions)

# %% [markdown]
# ## Project 2_11

# %%
# %%capture
proj_2_11_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_11_yr_21_combined_pixel_ob.csv')
proj_2_11_21 = proj_2_11_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_11_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_11_yr_20_pixel.csv')
proj_2_11_20 = proj_2_11_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_11_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_11_yr_19_pixel.csv')
proj_2_11_19 = proj_2_11_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_11_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_11_yr_18_pixel.csv')
proj_2_11_18 = proj_2_11_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_11_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_11_yr_17_pixel.csv')
proj_2_11_17 = proj_2_11_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_11_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_11_yr_16_pixel.csv')
proj_2_11_16 = proj_2_11_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_11_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_11_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_11_predictions = proj_2_11_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_11_predictions)

# %% [markdown]
# ## Project 2_12

# %%
# %%capture
proj_2_12_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_12_yr_21_combined_pixel_ob.csv')
proj_2_12_21 = proj_2_12_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_12_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_12_yr_20_pixel.csv')
proj_2_12_20 = proj_2_12_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_12_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_12_yr_19_pixel.csv')
proj_2_12_19 = proj_2_12_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_12_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_12_yr_18_pixel.csv')
proj_2_12_18 = proj_2_12_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_12_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_12_yr_17_pixel.csv')
proj_2_12_17 = proj_2_12_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_12_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_12_yr_16_pixel.csv')
proj_2_12_16 = proj_2_12_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_12_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_12_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_12_predictions = proj_2_12_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_12_predictions)

# %% [markdown]
# ## Project 2_13

# %%
# %%capture
proj_2_13_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_13_yr_21_combined_pixel_ob.csv')
proj_2_13_21 = proj_2_13_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_13_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_13_yr_20_pixel.csv')
proj_2_13_20 = proj_2_13_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_13_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_13_yr_19_pixel.csv')
proj_2_13_19 = proj_2_13_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_13_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_13_yr_18_pixel.csv')
proj_2_13_18 = proj_2_13_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_13_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_13_yr_17_pixel.csv')
proj_2_13_17 = proj_2_13_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_13_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_13_yr_16_pixel.csv')
proj_2_13_16 = proj_2_13_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_13_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_13_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_13_predictions = proj_2_13_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_13_predictions)

# %% [markdown]
# ## Project 2_14

# %%
# %%capture
proj_2_14_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_14_yr_21_combined_pixel_ob.csv')
proj_2_14_21 = proj_2_14_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_14_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_14_yr_20_pixel.csv')
proj_2_14_20 = proj_2_14_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_14_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_14_yr_19_pixel.csv')
proj_2_14_19 = proj_2_14_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_14_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_14_yr_18_pixel.csv')
proj_2_14_18 = proj_2_14_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_14_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_14_yr_17_pixel.csv')
proj_2_14_17 = proj_2_14_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_14_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_14_yr_16_pixel.csv')
proj_2_14_16 = proj_2_14_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_14_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_14_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_14_predictions = proj_2_14_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_14_predictions)

# %% [markdown]
# ## Project 2_15

# %%
# %%capture
proj_2_15_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_15_yr_21_combined_pixel_ob.csv')
proj_2_15_21 = proj_2_15_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_15_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_15_yr_20_pixel.csv')
proj_2_15_20 = proj_2_15_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_15_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_15_yr_19_pixel.csv')
proj_2_15_19 = proj_2_15_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_15_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_15_yr_18_pixel.csv')
proj_2_15_18 = proj_2_15_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_15_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_15_yr_17_pixel.csv')
proj_2_15_17 = proj_2_15_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_15_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_15_yr_16_pixel.csv')
proj_2_15_16 = proj_2_15_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_15_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_15_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_15_predictions = proj_2_15_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_15_predictions)

# %% [markdown]
# ## Project 2_16

# %%
# %%capture
proj_2_16_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_16_yr_21_combined_pixel_ob.csv')
proj_2_16_21 = proj_2_16_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_16_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_16_yr_20_pixel.csv')
proj_2_16_20 = proj_2_16_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_16_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_16_yr_19_pixel.csv')
proj_2_16_19 = proj_2_16_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_16_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_16_yr_18_pixel.csv')
proj_2_16_18 = proj_2_16_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_16_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_16_yr_17_pixel.csv')
proj_2_16_17 = proj_2_16_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_16_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_16_yr_16_pixel.csv')
proj_2_16_16 = proj_2_16_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_16_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_16_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_16_predictions = proj_2_16_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_16_predictions)

# %% [markdown]
# ## Project 2_18

# %%
# %%capture
proj_2_18_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_18_yr_21_combined_pixel_ob.csv')
proj_2_18_21 = proj_2_18_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_18_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_18_yr_20_pixel.csv')
proj_2_18_20 = proj_2_18_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_18_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_18_yr_19_pixel.csv')
proj_2_18_19 = proj_2_18_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_18_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_18_yr_18_pixel.csv')
proj_2_18_18 = proj_2_18_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_18_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_18_yr_17_pixel.csv')
proj_2_18_17 = proj_2_18_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_18_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_18_yr_16_pixel.csv')
proj_2_18_16 = proj_2_18_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_18_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_18_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_18_predictions = proj_2_18_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_18_predictions)

# %% [markdown]
# ## Project 2_19

# %%
# %%capture
proj_2_19_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_19_yr_21_combined_pixel_ob.csv')
proj_2_19_21 = proj_2_19_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_19_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_19_yr_20_pixel.csv')
proj_2_19_20 = proj_2_19_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_19_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_19_yr_19_pixel.csv')
proj_2_19_19 = proj_2_19_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_19_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_19_yr_18_pixel.csv')
proj_2_19_18 = proj_2_19_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_19_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_19_yr_17_pixel.csv')
proj_2_19_17 = proj_2_19_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_19_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_19_yr_16_pixel.csv')
proj_2_19_16 = proj_2_19_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_19_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_19_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_19_predictions = proj_2_19_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_19_predictions)

# %% [markdown]
# ## Project 2_20

# %%
# %%capture
proj_2_20_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_20_yr_21_combined_pixel_ob.csv')
proj_2_20_21 = proj_2_20_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_20_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_20_yr_20_pixel.csv')
proj_2_20_20 = proj_2_20_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_20_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_20_yr_19_pixel.csv')
proj_2_20_19 = proj_2_20_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_20_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_20_yr_18_pixel.csv')
proj_2_20_18 = proj_2_20_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_20_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_20_yr_17_pixel.csv')
proj_2_20_17 = proj_2_20_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_20_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_20_yr_16_pixel.csv')
proj_2_20_16 = proj_2_20_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_20_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_20_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_20_predictions = proj_2_20_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_20_predictions)

# %% [markdown]
# ##Project 2_21

# %%
# %%capture
proj_2_21_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_21_yr_21_combined_pixel_ob.csv')
proj_2_21_21 = proj_2_21_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_21_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_21_yr_20_pixel.csv')
proj_2_21_20 = proj_2_21_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_21_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_21_yr_19_pixel.csv')
proj_2_21_19 = proj_2_21_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_21_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_21_yr_18_pixel.csv')
proj_2_21_18 = proj_2_21_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_21_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_21_yr_17_pixel.csv')
proj_2_21_17 = proj_2_21_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_21_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_21_yr_16_pixel.csv')
proj_2_21_16 = proj_2_21_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_21_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_21_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_21_predictions = proj_2_21_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_21_predictions)

# %% [markdown]
# ##Project 2_22

# %%
# %%capture
proj_2_22_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_22_yr_21_combined_pixel_ob.csv')
proj_2_22_21 = proj_2_22_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_22_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_22_yr_20_pixel.csv')
proj_2_22_20 = proj_2_22_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_22_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_22_yr_19_pixel.csv')
proj_2_22_19 = proj_2_22_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_22_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_22_yr_18_pixel.csv')
proj_2_22_18 = proj_2_22_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_22_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_22_yr_17_pixel.csv')
proj_2_22_17 = proj_2_22_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_22_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_22_yr_16_pixel.csv')
proj_2_22_16 = proj_2_22_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_22_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_22_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_22_predictions = proj_2_22_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_22_predictions)

# %% [markdown]
# ##Proejct 2_23

# %%
# %%capture
proj_2_23_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_23_yr_21_combined_pixel_ob.csv')
proj_2_23_21 = proj_2_23_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_23_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_23_yr_20_pixel.csv')
proj_2_23_20 = proj_2_23_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_23_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_23_yr_19_pixel.csv')
proj_2_23_19 = proj_2_23_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_23_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_23_yr_18_pixel.csv')
proj_2_23_18 = proj_2_23_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_23_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_23_yr_17_pixel.csv')
proj_2_23_17 = proj_2_23_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_23_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_23_yr_16_pixel.csv')
proj_2_23_16 = proj_2_23_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_23_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_23_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_23_predictions = proj_2_23_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_23_predictions)

# %% [markdown]
# ##Project 2_24

# %%
# %%capture
proj_2_24_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_24_yr_21_combined_pixel_ob.csv')
proj_2_24_21 = proj_2_24_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_24_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_24_yr_20_pixel.csv')
proj_2_24_20 = proj_2_24_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_24_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_24_yr_19_pixel.csv')
proj_2_24_19 = proj_2_24_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#proj_2_24_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_24_yr_18_pixel.csv')
#proj_2_24_18 = proj_2_24_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_24_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_24_yr_17_pixel.csv')
proj_2_24_17 = proj_2_24_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_24_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_24_yr_16_pixel.csv')
proj_2_24_16 = proj_2_24_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_24_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_24_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_24_predictions = proj_2_24_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_24_predictions)

# %% [markdown]
# ##Project 2_25

# %%
# %%capture
proj_2_25_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_25_yr_21_combined_pixel_ob.csv')
proj_2_25_21 = proj_2_25_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_25_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_25_yr_20_pixel.csv')
proj_2_25_20 = proj_2_25_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_25_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_25_yr_19_pixel.csv')
proj_2_25_19 = proj_2_25_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_25_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_25_yr_18_pixel.csv')
proj_2_25_18 = proj_2_25_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_25_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_25_yr_17_pixel.csv')
proj_2_25_17 = proj_2_25_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_25_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_25_yr_16_pixel.csv')
proj_2_25_16 = proj_2_25_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_25_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_25_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_25_predictions = proj_2_25_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_25_predictions)

# %% [markdown]
# ##Project 2_26

# %%
# %%capture
proj_2_26_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_26_yr_21_combined_pixel_ob.csv')
proj_2_26_21 = proj_2_26_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_26_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_26_yr_20_pixel.csv')
proj_2_26_20 = proj_2_26_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_26_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_26_yr_19_pixel.csv')
proj_2_26_19 = proj_2_26_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_26_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_26_yr_18_pixel.csv')
proj_2_26_18 = proj_2_26_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_26_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_26_yr_17_pixel.csv')
proj_2_26_17 = proj_2_26_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_26_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_26_yr_16_pixel.csv')
proj_2_26_16 = proj_2_26_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_26_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_26_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_26_predictions = proj_2_26_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_26_predictions)

# %% [markdown]
# ##Project 2_27

# %%
# %%capture
proj_2_27_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_27_yr_21_combined_pixel_ob.csv')
proj_2_27_21 = proj_2_27_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_27_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_27_yr_20_pixel.csv')
proj_2_27_20 = proj_2_27_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_27_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_27_yr_19_pixel.csv')
proj_2_27_19 = proj_2_27_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_27_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_27_yr_18_pixel.csv')
proj_2_27_18 = proj_2_27_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_27_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_27_yr_17_pixel.csv')
proj_2_27_17 = proj_2_27_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_27_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_27_yr_16_pixel.csv')
proj_2_27_16 = proj_2_27_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_27_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_27_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_27_predictions = proj_2_27_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_27_predictions)

# %% [markdown]
# ##Project 2_28

# %%
# %%capture
proj_2_28_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_2_28_yr_21_combined_pixel_ob.csv')
proj_2_28_21 = proj_2_28_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_28_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_28_yr_20_pixel.csv')
proj_2_28_20 = proj_2_28_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_28_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_28_yr_19_pixel.csv')
proj_2_28_19 = proj_2_28_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_28_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_28_yr_18_pixel.csv')
proj_2_28_18 = proj_2_28_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_28_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_28_yr_17_pixel.csv')
proj_2_28_17 = proj_2_28_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_2_28_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_2_28_yr_16_pixel.csv')
proj_2_28_16 = proj_2_28_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_2_28_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_2_28_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_2_28_predictions = proj_2_28_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_2_28_predictions)

# %% [markdown]
# ##Project 4_8

# %%
# %%capture
proj_4_8_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_4_8_yr_21_combined_pixel_ob.csv')
proj_4_8_21 = proj_4_8_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_8_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_8_yr_20_pixel.csv')
proj_4_8_20 = proj_4_8_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_8_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_8_yr_19_pixel.csv')
proj_4_8_19 = proj_4_8_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_8_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_8_yr_18_pixel.csv')
proj_4_8_18 = proj_4_8_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_8_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_8_yr_17_pixel.csv')
proj_4_8_17 = proj_4_8_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_8_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_8_yr_16_pixel.csv')
proj_4_8_16 = proj_4_8_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_4_8_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_4_8_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_4_8_predictions = proj_4_8_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_4_8_predictions)

# %% [markdown]
# ##Project 4_9

# %%
# %%capture
proj_4_9_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_4_9_yr_21_combined_pixel_ob.csv')
proj_4_9_21 = proj_4_9_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_9_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_9_yr_20_pixel.csv')
proj_4_9_20 = proj_4_9_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_9_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_9_yr_19_pixel.csv')
proj_4_9_19 = proj_4_9_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_9_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_9_yr_18_pixel.csv')
proj_4_9_18 = proj_4_9_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_9_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_9_yr_17_pixel.csv')
proj_4_9_17 = proj_4_9_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_9_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_9_yr_16_pixel.csv')
proj_4_9_16 = proj_4_9_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_4_9_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_4_9_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_4_9_predictions = proj_4_9_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_4_9_predictions)

# %% [markdown]
# ##Project 4_13

# %%
# %%capture
proj_4_13_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_4_13_yr_21_combined_pixel_ob.csv')
proj_4_13_21 = proj_4_13_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_13_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_13_yr_20_pixel.csv')
proj_4_13_20 = proj_4_13_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_13_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_13_yr_19_pixel.csv')
proj_4_13_19 = proj_4_13_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_13_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_13_yr_18_pixel.csv')
proj_4_13_18 = proj_4_13_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#proj_4_13_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_13_yr_17_pixel.csv')
#proj_4_13_17 = proj_4_13_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#proj_4_13_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_13_yr_16_pixel.csv')
#proj_4_13_16 = proj_4_13_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_4_13_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_4_13_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_4_13_predictions = proj_4_13_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_4_13_predictions)

# %% [markdown]
# ##Project 4_21

# %%
# %%capture
proj_4_21_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_4_21_yr_21_combined_pixel_ob.csv')
proj_4_21_21 = proj_4_21_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_21_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_21_yr_20_pixel.csv')
proj_4_21_20 = proj_4_21_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_21_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_21_yr_19_pixel.csv')
proj_4_21_19 = proj_4_21_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_21_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_21_yr_18_pixel.csv')
proj_4_21_18 = proj_4_21_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_21_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_21_yr_17_pixel.csv')
proj_4_21_17 = proj_4_21_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_4_21_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_21_yr_16_pixel.csv')
proj_4_21_16 = proj_4_21_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_4_21_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_4_21_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_4_21_predictions = proj_4_21_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_4_21_predictions)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-39-b6efea6a335b> in <cell line: 1>()
# ----> 1 proj_4_21_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_4_21_yr_21_combined_pixel_ob.csv')
#       2 proj_4_21_21 = proj_4_21_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#       3 proj_4_21_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_21_yr_20_pixel.csv')
#       4 proj_4_21_20 = proj_4_21_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#       5 proj_4_21_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_4_21_yr_19_pixel.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %% [markdown]
# ##Project 7_2

# %%
# %%capture
proj_7_2_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_7_2_yr_21_combined_pixel_ob.csv')
proj_7_2_21 = proj_7_2_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_2_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_2_yr_20_pixel.csv')
proj_7_2_20 = proj_7_2_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_2_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_2_yr_19_pixel.csv')
proj_7_2_19 = proj_7_2_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_2_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_2_yr_18_pixel.csv')
proj_7_2_18 = proj_7_2_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_2_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_2_yr_17_pixel.csv')
proj_7_2_17 = proj_7_2_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_2_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_2_yr_16_pixel.csv')
proj_7_2_16 = proj_7_2_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_7_2_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_7_2_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_7_2_predictions = proj_7_2_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_7_2_predictions)

# %% [markdown]
# ##Project 7_3

# %%
# %%capture
proj_7_3_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_7_3_yr_21_combined_pixel_ob.csv')
proj_7_3_21 = proj_7_3_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_3_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_3_yr_20_pixel.csv')
proj_7_3_20 = proj_7_3_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_3_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_3_yr_19_pixel.csv')
proj_7_3_19 = proj_7_3_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_3_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_3_yr_18_pixel.csv')
proj_7_3_18 = proj_7_3_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_3_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_3_yr_17_pixel.csv')
proj_7_3_17 = proj_7_3_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_3_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_3_yr_16_pixel.csv')
proj_7_3_16 = proj_7_3_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_7_3_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_7_3_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_7_3_predictions = proj_7_3_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_7_3_predictions)

# %% [markdown]
# ##Project 7_4

# %%
# %%capture
proj_7_4_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_7_4_yr_21_combined_pixel_ob.csv')
proj_7_4_21 = proj_7_4_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_4_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_4_yr_20_pixel.csv')
proj_7_4_20 = proj_7_4_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#proj_7_4_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_4_yr_19_pixel.csv')
#proj_7_4_19 = proj_7_4_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_4_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_4_yr_18_pixel.csv')
proj_7_4_18 = proj_7_4_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_4_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_4_yr_17_pixel.csv')
proj_7_4_17 = proj_7_4_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_4_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_4_yr_16_pixel.csv')
proj_7_4_16 = proj_7_4_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2021]

# Initialize an empty summary DataFrame
proj_7_4_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_7_4_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_7_4_predictions = proj_7_4_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_7_4_predictions)

# %% [markdown]
# ##Project 7_6

# %%
# %%capture
proj_7_6_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_7_6_yr_21_combined_pixel_ob.csv')
proj_7_6_21 = proj_7_6_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#proj_7_6_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_6_yr_20_pixel.csv')
#proj_7_6_20 = proj_7_6_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_6_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_6_yr_19_pixel.csv')
proj_7_6_19 = proj_7_6_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_6_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_6_yr_18_pixel.csv')
proj_7_6_18 = proj_7_6_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_6_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_6_yr_17_pixel.csv')
proj_7_6_17 = proj_7_6_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_6_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_6_yr_16_pixel.csv')
proj_7_6_16 = proj_7_6_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2021]

# Initialize an empty summary DataFrame
proj_7_6_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_7_6_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_7_6_predictions = proj_7_6_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_7_6_predictions)

# %% [markdown]
# ##Project 7_7

# %%
# %%capture
proj_7_7_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_7_7_yr_21_combined_pixel_ob.csv')
proj_7_7_21 = proj_7_7_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#proj_7_7_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_7_yr_20_pixel.csv')
#proj_7_7_20 = proj_7_7_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_7_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_7_yr_19_pixel.csv')
proj_7_7_19 = proj_7_7_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_7_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_7_yr_18_pixel.csv')
proj_7_7_18 = proj_7_7_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_7_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_7_yr_17_pixel.csv')
proj_7_7_17 = proj_7_7_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#proj_7_7_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_7_yr_16_pixel.csv')
#proj_7_7_16 = proj_7_7_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2017, 2018, 2019, 2021]

# Initialize an empty summary DataFrame
proj_7_7_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_7_7_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_7_7_predictions = proj_7_7_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_7_7_predictions)

# %% [markdown]
# ##Project 7_10

# %%
# %%capture
proj_7_10_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_7_10_yr_21_combined_pixel_ob.csv')
proj_7_10_21 = proj_7_10_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_10_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_10_yr_20_pixel.csv')
proj_7_10_20 = proj_7_10_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_10_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_10_yr_19_pixel.csv')
proj_7_10_19 = proj_7_10_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_10_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_10_yr_18_pixel.csv')
proj_7_10_18 = proj_7_10_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_10_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_10_yr_17_pixel.csv')
proj_7_10_17 = proj_7_10_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_10_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_10_yr_16_pixel.csv')
proj_7_10_16 = proj_7_10_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_7_10_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_7_10_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_7_10_predictions = proj_7_10_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_7_10_predictions)

# %% [markdown]
# ##Project 7_12

# %%
# %%capture
proj_7_12_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_7_12_yr_21_combined_pixel_ob.csv')
proj_7_12_21 = proj_7_12_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_12_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_12_yr_20_pixel.csv')
proj_7_12_20 = proj_7_12_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_12_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_12_yr_19_pixel.csv')
proj_7_12_19 = proj_7_12_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_12_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_12_yr_18_pixel.csv')
proj_7_12_18 = proj_7_12_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_12_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_12_yr_17_pixel.csv')
proj_7_12_17 = proj_7_12_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#proj_7_12_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_12_yr_16_pixel.csv')
#proj_7_12_16 = proj_7_12_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_7_12_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_7_12_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_7_12_predictions = proj_7_12_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_7_12_predictions)

# %% [markdown]
# ##Project 7_13

# %%
# %%capture
proj_7_13_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_7_13_yr_21_combined_pixel_ob.csv')
proj_7_13_21 = proj_7_13_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_13_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_13_yr_20_pixel.csv')
proj_7_13_20 = proj_7_13_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_13_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_13_yr_19_pixel.csv')
proj_7_13_19 = proj_7_13_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#proj_7_13_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_13_yr_18_pixel.csv')
#proj_7_13_18 = proj_7_13_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_13_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_13_yr_17_pixel.csv')
proj_7_13_17 = proj_7_13_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_13_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_13_yr_16_pixel.csv')
proj_7_13_16 = proj_7_13_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_7_13_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_7_13_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_7_13_predictions = proj_7_13_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_7_13_predictions)

# %% [markdown]
# ##Project 7_14

# %%
# %%capture
proj_7_14_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_7_14_yr_21_combined_pixel_ob.csv')
proj_7_14_21 = proj_7_14_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_14_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_14_yr_20_pixel.csv')
proj_7_14_20 = proj_7_14_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_14_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_14_yr_19_pixel.csv')
proj_7_14_19 = proj_7_14_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_14_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_14_yr_18_pixel.csv')
proj_7_14_18 = proj_7_14_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_14_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_14_yr_17_pixel.csv')
proj_7_14_17 = proj_7_14_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_14_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_14_yr_16_pixel.csv')
proj_7_14_16 = proj_7_14_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_7_14_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_7_14_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_7_14_predictions = proj_7_14_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_7_14_predictions)

# %% [markdown]
# ##Project 7_15

# %%
# %%capture
proj_7_15_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_7_15_yr_21_combined_pixel_ob.csv')
proj_7_15_21 = proj_7_15_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_15_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_15_yr_20_pixel.csv')
proj_7_15_20 = proj_7_15_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_15_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_15_yr_19_pixel.csv')
proj_7_15_19 = proj_7_15_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_15_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_15_yr_18_pixel.csv')
proj_7_15_18 = proj_7_15_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_15_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_15_yr_17_pixel.csv')
proj_7_15_17 = proj_7_15_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_7_15_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_7_15_yr_16_pixel.csv')
proj_7_15_16 = proj_7_15_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_7_15_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_7_15_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_7_15_predictions = proj_7_15_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_7_15_predictions)

# %% [markdown]
# ##Project 10_1

# %%
# %%capture
proj_10_1_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_10_1_yr_21_combined_pixel_ob.csv')
proj_10_1_21 = proj_10_1_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_10_1_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_10_1_yr_20_pixel.csv')
proj_10_1_20 = proj_10_1_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_10_1_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_10_1_yr_19_pixel.csv')
proj_10_1_19 = proj_10_1_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_10_1_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_10_1_yr_18_pixel.csv')
proj_10_1_18 = proj_10_1_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#proj_10_1_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_10_1_yr_17_pixel.csv')
#proj_10_1_17 = proj_10_1_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_10_1_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_10_1_yr_16_pixel.csv')
proj_10_1_16 = proj_10_1_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_10_1_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_10_1_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_10_1_predictions = proj_10_1_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_10_1_predictions)

# %% [markdown]
# ##Project 10_2

# %%
# %%capture
proj_10_2_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_10_2_yr_21_combined_pixel_ob.csv')
proj_10_2_21 = proj_10_2_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_10_2_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_10_2_yr_20_pixel.csv')
proj_10_2_20 = proj_10_2_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_10_2_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_10_2_yr_19_pixel.csv')
proj_10_2_19 = proj_10_2_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_10_2_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_10_2_yr_18_pixel.csv')
proj_10_2_18 = proj_10_2_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_10_2_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_10_2_yr_17_pixel.csv')
proj_10_2_17 = proj_10_2_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_10_2_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_10_2_yr_16_pixel.csv')
proj_10_2_16 = proj_10_2_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_10_2_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_10_2_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_10_2_predictions = proj_10_2_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_10_2_predictions)

# %% [markdown]
# ##Project 10_3

# %%
# %%capture
proj_10_3_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_10_3_yr_21_combined_pixel_ob.csv')
proj_10_3_21 = proj_10_3_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_10_3_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_10_3_yr_20_pixel.csv')
proj_10_3_20 = proj_10_3_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_10_3_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_10_3_yr_19_pixel.csv')
proj_10_3_19 = proj_10_3_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#proj_10_3_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_10_3_yr_18_pixel.csv')
#proj_10_3_18 = proj_10_3_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_10_3_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_10_3_yr_17_pixel.csv')
proj_10_3_17 = proj_10_3_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#proj_10_3_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_10_3_yr_16_pixel.csv')
#proj_10_3_16 = proj_10_3_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2017, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_10_3_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_10_3_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_10_3_predictions = proj_10_3_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_10_3_predictions)

# %% [markdown]
# ##Project 13_10

# %%
# %%capture
proj_13_10_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_13_10_yr_21_combined_pixel_ob.csv')
proj_13_10_21 = proj_13_10_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_13_10_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_13_10_yr_20_pixel.csv')
proj_13_10_20 = proj_13_10_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_13_10_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_13_10_yr_19_pixel.csv')
proj_13_10_19 = proj_13_10_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
#proj_13_10_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_13_10_yr_18_pixel.csv')
#proj_13_10_18 = proj_13_10_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_13_10_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_13_10_yr_17_pixel.csv')
proj_13_10_17 = proj_13_10_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_13_10_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_13_10_yr_16_pixel.csv')
proj_13_10_16 = proj_13_10_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_13_10_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_13_10_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_13_10_predictions = proj_13_10_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_13_10_predictions)

# %% [markdown]
# ##Project 16_3

# %%
# %%capture
proj_16_3_21 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/3_combined_pixel_ob_data/proj_16_3_yr_21_combined_pixel_ob.csv')
proj_16_3_21 = proj_16_3_21[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_16_3_20 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_16_3_yr_20_pixel.csv')
proj_16_3_20 = proj_16_3_20[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_16_3_19 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_16_3_yr_19_pixel.csv')
proj_16_3_19 = proj_16_3_19[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_16_3_18 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_16_3_yr_18_pixel.csv')
proj_16_3_18 = proj_16_3_18[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_16_3_17 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_16_3_yr_17_pixel.csv')
proj_16_3_17 = proj_16_3_17[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]
proj_16_3_16 = pd.read_csv('https://raw.githubusercontent.com/andrewwells991/mds_thesis/main/data/4_ee_pixel_data_other_yrs/malawi_proj_16_3_yr_16_pixel.csv')
proj_16_3_16 = proj_16_3_16[['B2', 'B3', 'B4', 'B8', 'B11', 'B12']]

# Define the list of years to include in the output DataFrame
years = [2016, 2017, 2018, 2019, 2020, 2021]

# Initialize an empty summary DataFrame
proj_16_3_predictions = pd.DataFrame(columns=['rf_over', 'year'])

# Loop through each year
for year in years:
    # Get the input DataFrame for the current year
    df_name = 'proj_16_3_' + str(year - 2000)
    df = globals()[df_name]

    # Run ml models
    rf_over_pred = rf_over.predict(df)

    # Create a dataframe with the predicted results
    predictions_df = pd.DataFrame({
        'rf_over': rf_over_pred,
    })

    # Calculate column sums
    rf_over_sum = predictions_df['rf_over'].sum()

    # Create a new row with the column sums and year value
    row = {
        'rf_over': rf_over_sum,
        'year': year
    }

    # Append the row to the summary DataFrame
    proj_16_3_predictions = proj_16_3_predictions.append(row, ignore_index=True)

# Print the resulting DataFrame
print(proj_16_3_predictions)

# %% [markdown]
# #Combine and save data

# %%
for df_name in [
    'proj_2_5_predictions',
    'proj_2_6_predictions',
    'proj_2_8_predictions',
    'proj_2_10_predictions',
    'proj_2_11_predictions',
    'proj_2_12_predictions',
    'proj_2_13_predictions',
    'proj_2_14_predictions',
    'proj_2_15_predictions',
    'proj_2_16_predictions',
    'proj_2_18_predictions',
    'proj_2_19_predictions',
    'proj_2_20_predictions',
    'proj_2_21_predictions',
    'proj_2_22_predictions',
    'proj_2_23_predictions',
    'proj_2_24_predictions',
    'proj_2_25_predictions',
    'proj_2_26_predictions',
    'proj_2_27_predictions',
    'proj_2_28_predictions',

    'proj_4_8_predictions',
    'proj_4_9_predictions',
    'proj_4_13_predictions',

    'proj_7_2_predictions',
    'proj_7_3_predictions',
    'proj_7_4_predictions',
    'proj_7_6_predictions',
    'proj_7_7_predictions',
    'proj_7_10_predictions',
    'proj_7_12_predictions',
    'proj_7_13_predictions',
    'proj_7_14_predictions',
    'proj_7_15_predictions',

    'proj_10_1_predictions',
    'proj_10_2_predictions',
    'proj_10_3_predictions',

    'proj_13_10_predictions',

    'proj_16_3_predictions']:

    # Extract the first part of the name of the dataframe
    proj_site = df_name.split('_predictions')[0]
    
    # Assign the value of proj_site to a new column in the dataframe
    globals()[df_name]['proj_site'] = proj_site

# %%
df = pd.concat([
    proj_2_5_predictions,
    proj_2_6_predictions,
    proj_2_8_predictions,
    proj_2_10_predictions,
    proj_2_11_predictions,
    proj_2_12_predictions,
    proj_2_13_predictions,
    proj_2_14_predictions,
    proj_2_15_predictions,
    proj_2_16_predictions,
    proj_2_18_predictions,
    proj_2_19_predictions,
    proj_2_20_predictions,
    proj_2_21_predictions,
    proj_2_22_predictions,
    proj_2_23_predictions,
    proj_2_24_predictions,
    proj_2_25_predictions,
    proj_2_26_predictions,
    proj_2_27_predictions,
    proj_2_28_predictions,

    proj_4_8_predictions,
    proj_4_9_predictions,
    proj_4_13_predictions,

    proj_7_2_predictions,
    proj_7_3_predictions,
    proj_7_4_predictions,
    proj_7_6_predictions,
    proj_7_7_predictions,
    proj_7_10_predictions,
    proj_7_12_predictions,
    proj_7_13_predictions,
    proj_7_14_predictions,
    proj_7_15_predictions,

    proj_10_1_predictions,
    proj_10_2_predictions,
    proj_10_3_predictions,

    proj_13_10_predictions,

    proj_16_3_predictions])

# %%
df
# Out:
#     rf_over    year  proj_site
# 0    2837.0  2016.0   proj_2_5
# 1    2321.0  2017.0   proj_2_5
# 2    6175.0  2018.0   proj_2_5
# 3    2799.0  2019.0   proj_2_5
# 4    5668.0  2020.0   proj_2_5
# ..      ...     ...        ...
# 1       6.0  2017.0  proj_16_3
# 2      15.0  2018.0  proj_16_3
# 3      14.0  2019.0  proj_16_3
# 4      20.0  2020.0  proj_16_3
# 5      83.0  2021.0  proj_16_3
#
# [220 rows x 3 columns]

# %%
from google.colab import files

df.to_csv('applied_rf.csv', encoding = 'utf-8-sig') 
files.download('applied_rf.csv')
